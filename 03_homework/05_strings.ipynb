# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here
str =  '''This is a multi line string 
I can type many line as text within the 
triple qoutes and
it will all be 
treated as a single string '''

str
# Out:
# 'This is a multi line string \nI can type many line as text within the \ntriple qoutes and\nit will all be \ntreated as a single string '

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here
str += 'world'

str
# Out:
# 'This is a multi line string \nI can type many line as text within the \ntriple qoutes and\nit will all be \ntreated as a single string world'
