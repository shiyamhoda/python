# %% [markdown]
# # How to sync changes from UofT-DSI repo to you local branch

# %% [markdown]
# Open your fork of the UofT-DSI repo and click on *`Sync fork`* button. Make sure you can see the forked from UofT-DSI/<repo_name> on top left corner as shown in the image below
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Our origin main branch is now in sync with the UofT-DSI repo. Next step is to get this updated version to our local repo in bash.
#
# adding this line just to git commit

# %% [markdown]
# Open bash in Visual Studio and navigate to the root folder of your repo. Your bash should look something like this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Make sure you are in the main branch as shown in the screenshot above. If you are not in the main branch, use the following command to switch to the main branch
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Use the following command to pull the updated repo to your local machine.
#
# ![image.png](attachment:image.png)
#
# Now all of your local files are in sync with the latest UofT-DSI repo code. You are good to start doing you homeowrk and assignments :)
